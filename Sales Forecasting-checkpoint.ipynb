# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
# from keras.optimizers import Adam .
from tensorflow.keras.optimizers import Adam # - Works
from tensorflow.keras.callbacks import EarlyStopping
from keras.utils import np_utils
from tensorflow.keras.layers import LSTM
from sklearn.model_selection import KFold, cross_val_score, train_test_split

# %%
df = pd.read_excel('Sales Report Detail_1.xlsx') #reading data excel file

# %%
df
# Out:
#                                     Sales Report Detail Unnamed: 1  \
# 0                                                   NaN        NaN
# 1                            Location: Blu`s Boba St.51        NaN
# 2                           Date: 01/04/2021-13/10/2021        NaN
# 3     Item Type: Add-On Topping,  Drink,  Extra Topping        NaN
# 4     Item Category: Brown Sugar Drink,  Extra Toppi...        NaN
# ...                                                 ...        ...
# 6278                                                NaN   14:52:52
# 6279                                                NaN   14:56:35
# 6280                                                NaN   15:06:48
# 6281                                   13/10/2021 Total        NaN
# 6282                                        Grand Total        NaN
#
#             Unnamed: 2 Unnamed: 3            Unnamed: 4 Unnamed: 5
# 0                  NaN        NaN                   NaN        NaN
# 1                  NaN        NaN                   NaN        NaN
# 2                  NaN        NaN                   NaN        NaN
# 3                  NaN        NaN                   NaN        NaN
# 4                  NaN        NaN                   NaN        NaN
# ...                ...        ...                   ...        ...
# 6278  Blu`s Boba St.51     603649       Strawberry Milk          2
# 6279  Blu`s Boba St.51     603650     Original Milk Tea          2
# 6280  Blu`s Boba St.51     603651  Caramel Crunchy Milk          2
# 6281               NaN        NaN                   NaN         57
# 6282               NaN        NaN                   NaN       7535
#
# [6283 rows x 6 columns]

# %% [markdown]
# # Preprocessing Data

# %%
df = df.loc[17:,:]

# %%
df.reset_index(inplace = True )

# %%
df.drop('index',axis = 1, inplace = True)
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.columns = df.loc[0]

# %%
df.drop(df.index[0], inplace = True)

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis = 1, inplace=True)

# %%
df.head(40)
# Out:
# 0               Date      Time          Location     Sales No  \
# 0         01/04/2021  09:39:12  Blu`s Boba St.51        60389
# 1                NaN  09:43:58  Blu`s Boba St.51        60390
# 2                NaN  09:45:23  Blu`s Boba St.51        60391
# 3                NaN  09:47:40  Blu`s Boba St.51        60392
# 4                NaN  10:50:45  Blu`s Boba St.51        60393
# 5                NaN  11:27:09  Blu`s Boba St.51        60394
# 6                NaN       NaN               NaN          NaN
# 7                NaN       NaN               NaN  60394 Total
# 8                NaN  11:45:35  Blu`s Boba St.51        60395
# 9                NaN  11:47:37  Blu`s Boba St.51        60396
# 10               NaN  11:49:11  Blu`s Boba St.51        60397
# 11               NaN       NaN               NaN          NaN
# 12               NaN       NaN               NaN  60397 Total
# 13               NaN  12:27:39  Blu`s Boba St.51        60398
# 14               NaN       NaN               NaN          NaN
# 15               NaN       NaN               NaN          NaN
# 16               NaN       NaN               NaN          NaN
# 17               NaN       NaN               NaN          NaN
# 18               NaN       NaN               NaN  60398 Total
# 19               NaN  13:00:39  Blu`s Boba St.51        60399
# 20               NaN       NaN               NaN          NaN
# 21               NaN       NaN               NaN  60399 Total
# 22               NaN  13:04:43  Blu`s Boba St.51        60400
# 23               NaN       NaN               NaN          NaN
# 24               NaN       NaN               NaN          NaN
# 25               NaN       NaN               NaN  60400 Total
# 26               NaN  13:21:42  Blu`s Boba St.51        60401
# 27               NaN  13:54:14  Blu`s Boba St.51        60402
# 28               NaN  14:07:12  Blu`s Boba St.51        60403
# 29               NaN  14:32:46  Blu`s Boba St.51        60404
# 30               NaN       NaN               NaN          NaN
# 31               NaN       NaN               NaN  60404 Total
# 32               NaN  15:25:05  Blu`s Boba St.51        60405
# 33               NaN  15:27:59  Blu`s Boba St.51        60406
# 34               NaN  15:49:23  Blu`s Boba St.51        60407
# 35               NaN  15:53:47  Blu`s Boba St.51        60408
# 36               NaN  16:38:35  Blu`s Boba St.51        60409
# 37  01/04/2021 Total       NaN               NaN          NaN
# 38        02/04/2021  09:16:22  Blu`s Boba St.51        60410
# 39               NaN  10:01:20  Blu`s Boba St.51        60411
#
# 0                    Item Name Qty Total
# 0             Brown Sugar Milk         2
# 1             Brown Sugar Milk         2
# 2             Brown Sugar Milk         1
# 3       Strawberry Matcha Milk         1
# 4       Passion Lime Green Tea         1
# 5                  Matcha Milk         1
# 6            Original Milk Tea         1
# 7                          NaN         2
# 8      Brown Sugar Matcha Milk         1
# 9         Brown Sugar Milk Tea         3
# 10     Brown Sugar Matcha Milk         2
# 11            Brown Sugar Milk         2
# 12                         NaN         4
# 13  Add Original Tapioca Pearl         1
# 14     Brown Sugar Matcha Milk         1
# 15        Brown Sugar Milk Tea         4
# 16                 Matcha Milk         1
# 17      Passion Lime Green Tea         1
# 18                         NaN         8
# 19        Brown Sugar Milk Tea         2
# 20      Strawberry Matcha Milk         1
# 21                         NaN         3
# 22  Add Original Tapioca Pearl         1
# 23            Jasmine Milk Tea         1
# 24      Passion Lime Green Tea         1
# 25                         NaN         3
# 26        Brown Sugar Milk Tea         1
# 27        Brown Sugar Milk Tea         2
# 28     Brown Sugar Matcha Milk         1
# 29        Brown Sugar Milk Tea         1
# 30            Jasmine Milk Tea         1
# 31                         NaN         2
# 32            Brown Sugar Milk         4
# 33        Brown Sugar Milk Tea         1
# 34            Jasmine Milk Tea         1
# 35        Brown Sugar Milk Tea         4
# 36           Original Milk Tea         1
# 37                         NaN        48
# 38                 Matcha Milk         1
# 39     Brown Sugar Matcha Milk         1

# %%
df.ffill(inplace=True)
# df.head(40)
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\pandas\core\frame.py:4468: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df=df[~df['Sales No'].str.contains("Total")]
# df.head(40)

# %%
df=df[~df['Date'].str.contains("Total")]
# df.head(40)

# %%
df=df[['Date','Item Name',"Qty Total"]]
# df.head(40)

# %%
# df.head(50)

# %%
df["Date"] = pd.to_datetime(df["Date"])
df["Date"]=df['Date'].dt.strftime('%d/%m/%Y')
sum_df = df.groupby(['Date','Item Name']).agg({'Qty Total': 'sum'})
sum_df=sum_df.reset_index()
sum_df["Date"] = pd.to_datetime(sum_df["Date"],infer_datetime_format=True)
sum_df.sort_values(by=['Date'], inplace=True, ascending=True)
sum_df["Date"]=sum_df['Date'].dt.strftime('%Y-%m-%d')
sum_df.head(10)
# Out:
#           Date                   Item Name  Qty Total
# 0   2021-04-01  Add Original Tapioca Pearl          2
# 1   2021-04-01     Brown Sugar Matcha Milk          5
# 2   2021-04-01            Brown Sugar Milk         11
# 3   2021-04-01        Brown Sugar Milk Tea         18
# 4   2021-04-01            Jasmine Milk Tea          3
# 5   2021-04-01                 Matcha Milk          2
# 6   2021-04-01           Original Milk Tea          2
# 7   2021-04-01      Passion Lime Green Tea          3
# 8   2021-04-01      Strawberry Matcha Milk          2
# 19  2021-04-02      Strawberry Matcha Milk          6

# %%
final_df=sum_df.copy()

# %%
final_df =final_df.groupby(['Item Name']).agg({'Qty Total': 'sum'})

# %%
final_df
# Out:
#                                  Qty Total
# Item Name
# Add Original Tapioca Pearl             336
# Black Tea                               55
# Brown Sugar Matcha Milk                348
# Brown Sugar Milk                       467
# Brown Sugar Milk Tea                  1647
# Caramel Crunchy Milk                    86
# Extra Brown Sugar Tapioca Pearl        125
# Extra Original Tapioca Pearl            28
# Jasmine Green Tea                      118
# Jasmine Milk Tea                       919
# Mango Lime Green Tea                   192
# Matcha Milk                            185
# Original Milk Tea                     1118
# Passion Lime Green Tea                 302
# Strawberry Matcha Milk                 252
# Strawberry Milk                        311
# Thai Lime Tea                          226
# Thai Milk Tea                          820

# %% [markdown]
# # Sales record of Brown Sugar Milk Tea

# %%
DataFrame=sum_df[sum_df['Item Name'].str.contains("Brown Sugar Milk Tea")]
DataFrame
# Out:
#            Date             Item Name  Qty Total
# 3    2021-04-01  Brown Sugar Milk Tea         18
# 13   2021-04-02  Brown Sugar Milk Tea         29
# 23   2021-04-03  Brown Sugar Milk Tea         24
# 34   2021-04-04  Brown Sugar Milk Tea         33
# 45   2021-04-05  Brown Sugar Milk Tea         52
# ..          ...                   ...        ...
# 763  2021-10-09  Brown Sugar Milk Tea          1
# 768  2021-10-10  Brown Sugar Milk Tea          2
# 774  2021-10-11  Brown Sugar Milk Tea          8
# 783  2021-10-12  Brown Sugar Milk Tea         11
# 856  2021-10-13  Brown Sugar Milk Tea          1
#
# [175 rows x 3 columns]

# %%
DataFrame.rename(columns = {'Date':'date','Qty Total':'sales'}, inplace = True)
df_sales=DataFrame.copy()
df_sales=df_sales[['date','sales']]
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\pandas\core\frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#create a new dataframe to model the difference
df_diff = df_sales.copy()

# %%
#add previous sales to the next row
df_diff['prev_sales'] = df_diff['sales'].shift(1)
#drop the null values and calculate the difference
df_diff = df_diff.dropna()

df_diff['diff'] = (df_diff['sales'] - df_diff['prev_sales'])

#create new dataframe from transformation from time series to supervised
df_supervised = df_diff.drop(['prev_sales'],axis=1)
df_supervised= df_supervised.append(pd.DataFrame({'date': pd.date_range(start=df_supervised.date.iloc[-1], periods=6, freq='D', closed='right')}))
#adding lags
for inc in range(1,13):
    field_name = 'lag_' + str(inc)
    df_supervised[field_name] = df_supervised['diff'].shift(inc)
    
#drop null values
df_supervised = df_supervised.dropna().reset_index(drop=True)

# %%
extraDates=pd.DataFrame({'date': pd.date_range(start=df_supervised.date.iloc[-1], periods=6, freq='d', closed='right')})
fdf=df_supervised.append(extraDates)
fdf['date'] = pd.to_datetime(fdf['date'], errors='coerce')
fdf["date"]=fdf['date'].dt.strftime('%Y-%m-%d')
fdf=fdf.reset_index()
fdf = fdf.drop(['index'],axis=1)

fdf.tail(20)
fdf=fdf.fillna(0)

# %%
# Import statsmodels.formula.api
import statsmodels.formula.api as smf 

# Define the regression formula
model = smf.ols(formula='diff ~ lag_1', data=df_supervised)

# Fit the regression
model_fit = model.fit()

# Extract the adjusted r-squared
regression_adj_rsq = model_fit.rsquared_adj
print(regression_adj_rsq)
# Out:
# 0.3117113448935508

# %%
# Import statsmodels.formula.api
import statsmodels.formula.api as smf 

# Define the regression formula
model = smf.ols(formula='diff ~ lag_1 + lag_2 + lag_3 + lag_4 + lag_5', data=df_supervised)

# Fit the regression
model_fit = model.fit()

# Extract the adjusted r-squared
regression_adj_rsq = model_fit.rsquared_adj
print(regression_adj_rsq)
# Out:
# 0.38241751925491674

# %%
# Import statsmodels.formula.api
import statsmodels.formula.api as smf 

# Define the regression formula
model = smf.ols(formula='diff ~ lag_1 + lag_2 + lag_3 + lag_4 + lag_5 + lag_6 + lag_7 + lag_8 + lag_9 + lag_10 + lag_11 + lag_12', data=df_supervised)

# Fit the regression
model_fit = model.fit()

# Extract the adjusted r-squared
regression_adj_rsq = model_fit.rsquared_adj
print(regression_adj_rsq)
# Out:
# 0.3855736197308749

# %%
#import MinMaxScaler and create a new dataframe for LSTM model
from sklearn.preprocessing import MinMaxScaler
df_model = fdf.drop(['sales','date'],axis=1)

# %%
#split train and test set
train_set, test_set = df_model[0:-30].values, df_model[-30:].values

# %%
#apply Min Max Scaler
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = scaler.fit(train_set)
# reshape training set
train_set = train_set.reshape(train_set.shape[0], train_set.shape[1])
train_set_scaled = scaler.transform(train_set)

# reshape test set
test_set = test_set.reshape(test_set.shape[0], test_set.shape[1])
test_set_scaled = scaler.transform(test_set)

# %%
train_set_scaled
# Out:
# array([[ 0.03846154,  0.25      ,  0.07692308, ...,  0.32692308,
#          0.05769231,  0.36538462],
#        [ 0.21153846,  0.03846154,  0.25      , ...,  0.51923077,
#          0.32692308,  0.05769231],
#        [ 0.13461538,  0.21153846,  0.03846154, ..., -0.73076923,
#          0.51923077,  0.32692308],
#        ...,
#        [ 0.23076923, -0.38461538,  0.5       , ...,  0.26923077,
#          0.26923077,  0.09615385],
#        [ 0.05769231,  0.23076923, -0.38461538, ..., -0.01923077,
#          0.26923077,  0.26923077],
#        [ 0.32692308,  0.05769231,  0.23076923, ...,  0.25      ,
#         -0.01923077,  0.26923077]])

# %%
X_train, y_train = train_set_scaled[:, 1:], train_set_scaled[:, 0:1]
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])

# %%
X_test, y_test = test_set_scaled[:, 1:], test_set_scaled[:, 0:1]
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %% [markdown]
# # Training LSTM  model

# %%
model = Sequential()
model.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2]), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae'])
model.fit(X_train, y_train, epochs=100, batch_size=1, validation_data=(X_test, y_test),verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 137/137 [==============================] - 5s 14ms/step - loss: 0.0473 - mae: 0.1298 - val_loss: 0.0113 - val_mae: 0.0783
# Epoch 2/100
# 137/137 [==============================] - 0s 4ms/step - loss: 0.0437 - mae: 0.1212 - val_loss: 0.0109 - val_mae: 0.0765
# Epoch 3/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0419 - mae: 0.1182 - val_loss: 0.0107 - val_mae: 0.0756
# Epoch 4/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0404 - mae: 0.1159 - val_loss: 0.0105 - val_mae: 0.0750
# Epoch 5/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0390 - mae: 0.1138 - val_loss: 0.0103 - val_mae: 0.0745
# Epoch 6/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0378 - mae: 0.1120 - val_loss: 0.0102 - val_mae: 0.0744
# Epoch 7/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0367 - mae: 0.1105 - val_loss: 0.0101 - val_mae: 0.0744
# Epoch 8/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0356 - mae: 0.1093 - val_loss: 0.0100 - val_mae: 0.0744
# Epoch 9/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0346 - mae: 0.1082 - val_loss: 0.0100 - val_mae: 0.0746
# Epoch 10/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0337 - mae: 0.1073 - val_loss: 0.0099 - val_mae: 0.0747
# Epoch 11/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0327 - mae: 0.1067 - val_loss: 0.0099 - val_mae: 0.0749
# Epoch 12/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0318 - mae: 0.1061 - val_loss: 0.0099 - val_mae: 0.0751
# Epoch 13/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0310 - mae: 0.1057 - val_loss: 0.0099 - val_mae: 0.0752
# Epoch 14/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0302 - mae: 0.1055 - val_loss: 0.0098 - val_mae: 0.0753
# Epoch 15/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0294 - mae: 0.1054 - val_loss: 0.0098 - val_mae: 0.0754
# Epoch 16/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0287 - mae: 0.1053 - val_loss: 0.0098 - val_mae: 0.0758
# Epoch 17/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0281 - mae: 0.1050 - val_loss: 0.0098 - val_mae: 0.0762
# Epoch 18/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0275 - mae: 0.1047 - val_loss: 0.0098 - val_mae: 0.0765
# Epoch 19/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0270 - mae: 0.1043 - val_loss: 0.0097 - val_mae: 0.0767
# Epoch 20/100
# 137/137 [==============================] - 1s 5ms/step - loss: 0.0265 - mae: 0.1040 - val_loss: 0.0097 - val_mae: 0.0768
# Epoch 21/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0260 - mae: 0.1037 - val_loss: 0.0097 - val_mae: 0.0769
# Epoch 22/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0256 - mae: 0.1033 - val_loss: 0.0096 - val_mae: 0.0768
# Epoch 23/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0252 - mae: 0.1028 - val_loss: 0.0095 - val_mae: 0.0767
# Epoch 24/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0248 - mae: 0.1023 - val_loss: 0.0095 - val_mae: 0.0765
# Epoch 25/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0245 - mae: 0.1018 - val_loss: 0.0094 - val_mae: 0.0763
# Epoch 26/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0242 - mae: 0.1013 - val_loss: 0.0094 - val_mae: 0.0760
# Epoch 27/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0238 - mae: 0.1008 - val_loss: 0.0093 - val_mae: 0.0758
# Epoch 28/100
# 137/137 [==============================] - 1s 5ms/step - loss: 0.0236 - mae: 0.1003 - val_loss: 0.0092 - val_mae: 0.0755
# Epoch 29/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0233 - mae: 0.0999 - val_loss: 0.0092 - val_mae: 0.0751
# Epoch 30/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0230 - mae: 0.0995 - val_loss: 0.0091 - val_mae: 0.0748
# Epoch 31/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0228 - mae: 0.0992 - val_loss: 0.0090 - val_mae: 0.0744
# Epoch 32/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0225 - mae: 0.0989 - val_loss: 0.0089 - val_mae: 0.0740
# Epoch 33/100
# 137/137 [==============================] - 1s 7ms/step - loss: 0.0223 - mae: 0.0986 - val_loss: 0.0089 - val_mae: 0.0737
# Epoch 34/100
# 137/137 [==============================] - 1s 5ms/step - loss: 0.0221 - mae: 0.0983 - val_loss: 0.0088 - val_mae: 0.0734
# Epoch 35/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0219 - mae: 0.0980 - val_loss: 0.0087 - val_mae: 0.0731
# Epoch 36/100
# 137/137 [==============================] - 1s 5ms/step - loss: 0.0217 - mae: 0.0977 - val_loss: 0.0086 - val_mae: 0.0728
# Epoch 37/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0216 - mae: 0.0974 - val_loss: 0.0086 - val_mae: 0.0725
# Epoch 38/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0970 - val_loss: 0.0085 - val_mae: 0.0721
# Epoch 39/100
# 137/137 [==============================] - 1s 4ms/step - loss: 0.0212 - mae: 0.0967 - val_loss: 0.0084 - val_mae: 0.0718
# Epoch 40/100
# 137/137 [==============================] - 1s 6ms/step - loss: 0.0211 - mae: 0.0964 - val_loss: 0.0084 - val_mae: 0.0715
# Epoch 41/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0209 - mae: 0.0960 - val_loss: 0.0083 - val_mae: 0.0713
# Epoch 42/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0208 - mae: 0.0957 - val_loss: 0.0083 - val_mae: 0.0710
# Epoch 43/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0207 - mae: 0.0953 - val_loss: 0.0082 - val_mae: 0.0708
# Epoch 44/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0205 - mae: 0.0950 - val_loss: 0.0081 - val_mae: 0.0705
# Epoch 45/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0204 - mae: 0.0946 - val_loss: 0.0081 - val_mae: 0.0703
# Epoch 46/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0203 - mae: 0.0943 - val_loss: 0.0080 - val_mae: 0.0701
# Epoch 47/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0202 - mae: 0.0939 - val_loss: 0.0080 - val_mae: 0.0699
# Epoch 48/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0200 - mae: 0.0936 - val_loss: 0.0079 - val_mae: 0.0697
# Epoch 49/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0199 - mae: 0.0932 - val_loss: 0.0079 - val_mae: 0.0695
# Epoch 50/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0198 - mae: 0.0929 - val_loss: 0.0079 - val_mae: 0.0694
# Epoch 51/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0197 - mae: 0.0925 - val_loss: 0.0078 - val_mae: 0.0692
# Epoch 52/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0196 - mae: 0.0922 - val_loss: 0.0078 - val_mae: 0.0691
# Epoch 53/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0195 - mae: 0.0918 - val_loss: 0.0077 - val_mae: 0.0690
# Epoch 54/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0194 - mae: 0.0915 - val_loss: 0.0077 - val_mae: 0.0688
# Epoch 55/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0193 - mae: 0.0911 - val_loss: 0.0077 - val_mae: 0.0687
# Epoch 56/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0192 - mae: 0.0907 - val_loss: 0.0076 - val_mae: 0.0686
# Epoch 57/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0191 - mae: 0.0904 - val_loss: 0.0076 - val_mae: 0.0685
# Epoch 58/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0190 - mae: 0.0900 - val_loss: 0.0076 - val_mae: 0.0685
# Epoch 59/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0189 - mae: 0.0897 - val_loss: 0.0076 - val_mae: 0.0684
# Epoch 60/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0188 - mae: 0.0893 - val_loss: 0.0075 - val_mae: 0.0683
# Epoch 61/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0187 - mae: 0.0890 - val_loss: 0.0075 - val_mae: 0.0683
# Epoch 62/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0186 - mae: 0.0886 - val_loss: 0.0075 - val_mae: 0.0683
# Epoch 63/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0185 - mae: 0.0883 - val_loss: 0.0075 - val_mae: 0.0683
# Epoch 64/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0185 - mae: 0.0880 - val_loss: 0.0075 - val_mae: 0.0683
# Epoch 65/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0184 - mae: 0.0877 - val_loss: 0.0074 - val_mae: 0.0683
# Epoch 66/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0183 - mae: 0.0874 - val_loss: 0.0074 - val_mae: 0.0684
# Epoch 67/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0182 - mae: 0.0871 - val_loss: 0.0074 - val_mae: 0.0684
# Epoch 68/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0181 - mae: 0.0868 - val_loss: 0.0074 - val_mae: 0.0685
# Epoch 69/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0180 - mae: 0.0865 - val_loss: 0.0074 - val_mae: 0.0685
# Epoch 70/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0179 - mae: 0.0862 - val_loss: 0.0074 - val_mae: 0.0686
# Epoch 71/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0178 - mae: 0.0859 - val_loss: 0.0074 - val_mae: 0.0686
# Epoch 72/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0177 - mae: 0.0856 - val_loss: 0.0074 - val_mae: 0.0687
# Epoch 73/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0176 - mae: 0.0852 - val_loss: 0.0074 - val_mae: 0.0687
# Epoch 74/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0175 - mae: 0.0849 - val_loss: 0.0074 - val_mae: 0.0688
# Epoch 75/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0175 - mae: 0.0846 - val_loss: 0.0074 - val_mae: 0.0689
# Epoch 76/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0174 - mae: 0.0842 - val_loss: 0.0074 - val_mae: 0.0689
# Epoch 77/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0173 - mae: 0.0839 - val_loss: 0.0074 - val_mae: 0.0690
# Epoch 78/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0172 - mae: 0.0835 - val_loss: 0.0074 - val_mae: 0.0691
# Epoch 79/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0171 - mae: 0.0832 - val_loss: 0.0074 - val_mae: 0.0692
# Epoch 80/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0170 - mae: 0.0829 - val_loss: 0.0074 - val_mae: 0.0692
# Epoch 81/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0169 - mae: 0.0827 - val_loss: 0.0074 - val_mae: 0.0693
# Epoch 82/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0168 - mae: 0.0824 - val_loss: 0.0074 - val_mae: 0.0694
# Epoch 83/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0167 - mae: 0.0821 - val_loss: 0.0074 - val_mae: 0.0695
# Epoch 84/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0166 - mae: 0.0818 - val_loss: 0.0074 - val_mae: 0.0696
# Epoch 85/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0165 - mae: 0.0815 - val_loss: 0.0074 - val_mae: 0.0697
# Epoch 86/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0164 - mae: 0.0812 - val_loss: 0.0074 - val_mae: 0.0698
# Epoch 87/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0163 - mae: 0.0808 - val_loss: 0.0074 - val_mae: 0.0699
# Epoch 88/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0162 - mae: 0.0805 - val_loss: 0.0074 - val_mae: 0.0700
# Epoch 89/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0161 - mae: 0.0802 - val_loss: 0.0074 - val_mae: 0.0700
# Epoch 90/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0160 - mae: 0.0798 - val_loss: 0.0074 - val_mae: 0.0701
# Epoch 91/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0159 - mae: 0.0794 - val_loss: 0.0074 - val_mae: 0.0702
# Epoch 92/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0158 - mae: 0.0791 - val_loss: 0.0075 - val_mae: 0.0703
# Epoch 93/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0157 - mae: 0.0788 - val_loss: 0.0075 - val_mae: 0.0704
# Epoch 94/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0156 - mae: 0.0784 - val_loss: 0.0075 - val_mae: 0.0705
# Epoch 95/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0155 - mae: 0.0781 - val_loss: 0.0075 - val_mae: 0.0706
# Epoch 96/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0154 - mae: 0.0778 - val_loss: 0.0075 - val_mae: 0.0707
# Epoch 97/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0153 - mae: 0.0774 - val_loss: 0.0075 - val_mae: 0.0708
# Epoch 98/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0152 - mae: 0.0771 - val_loss: 0.0075 - val_mae: 0.0709
# Epoch 99/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.0151 - mae: 0.0767 - val_loss: 0.0075 - val_mae: 0.0710
# Epoch 100/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.0150 - mae: 0.0764 - val_loss: 0.0076 - val_mae: 0.0711

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
model=loaded_model
# Out:
# Loaded model from disk

# %%
y_pred = model.predict(X_test,batch_size=1)
# y_pred

# %%
#reshape y_pred
y_pred = y_pred.reshape(y_pred.shape[0], 1, y_pred.shape[1])

# %%
import numpy as np

# %%
#rebuild test set for inverse transform
pred_test_set = []
for index in range(0,len(y_pred)):
    print(np.concatenate([y_pred[index],X_test[index]],axis=1))
    pred_test_set.append(np.concatenate([y_pred[index],X_test[index]],axis=1))
# Out:
# [[ 0.09790614  0.32692308  0.05769231  0.23076923 -0.38461538  0.5
#    0.30769231  0.01923077  0.26923077  0.21153846 -0.01923077  0.25
#   -0.01923077]]
# [[ 7.71160871e-02  1.11022302e-16  3.26923077e-01  5.76923077e-02
#    2.30769231e-01 -3.84615385e-01  5.00000000e-01  3.07692308e-01
#    1.92307692e-02  2.69230769e-01  2.11538462e-01 -1.92307692e-02
#    2.50000000e-01]]
# [[ 1.19272128e-01  1.53846154e-01  1.11022302e-16  3.26923077e-01
#    5.76923077e-02  2.30769231e-01 -3.84615385e-01  5.00000000e-01
#    3.07692308e-01  1.92307692e-02  2.69230769e-01  2.11538462e-01
#   -1.92307692e-02]]
# [[ 1.40003845e-01  1.73076923e-01  1.53846154e-01  1.11022302e-16
#    3.26923077e-01  5.76923077e-02  2.30769231e-01 -3.84615385e-01
#    5.00000000e-01  3.07692308e-01  1.92307692e-02  2.69230769e-01
#    2.11538462e-01]]
# [[ 1.48555562e-01  2.11538462e-01  1.73076923e-01  1.53846154e-01
#    1.11022302e-16  3.26923077e-01  5.76923077e-02  2.30769231e-01
#   -3.84615385e-01  5.00000000e-01  3.07692308e-01  1.92307692e-02
#    2.69230769e-01]]
# [[ 1.66011363e-01  1.92307692e-01  2.11538462e-01  1.73076923e-01
#    1.53846154e-01  1.11022302e-16  3.26923077e-01  5.76923077e-02
#    2.30769231e-01 -3.84615385e-01  5.00000000e-01  3.07692308e-01
#    1.92307692e-02]]
# [[ 2.04669818e-01  7.69230769e-02  1.92307692e-01  2.11538462e-01
#    1.73076923e-01  1.53846154e-01  1.11022302e-16  3.26923077e-01
#    5.76923077e-02  2.30769231e-01 -3.84615385e-01  5.00000000e-01
#    3.07692308e-01]]
# [[ 1.92672387e-01  1.34615385e-01  7.69230769e-02  1.92307692e-01
#    2.11538462e-01  1.73076923e-01  1.53846154e-01  1.11022302e-16
#    3.26923077e-01  5.76923077e-02  2.30769231e-01 -3.84615385e-01
#    5.00000000e-01]]
# [[ 1.59492001e-01  1.73076923e-01  1.34615385e-01  7.69230769e-02
#    1.92307692e-01  2.11538462e-01  1.73076923e-01  1.53846154e-01
#    1.11022302e-16  3.26923077e-01  5.76923077e-02  2.30769231e-01
#   -3.84615385e-01]]
# [[1.11652754e-01 2.69230769e-01 1.73076923e-01 1.34615385e-01
#   7.69230769e-02 1.92307692e-01 2.11538462e-01 1.73076923e-01
#   1.53846154e-01 1.11022302e-16 3.26923077e-01 5.76923077e-02
#   2.30769231e-01]]
# [[2.28706077e-01 5.76923077e-02 2.69230769e-01 1.73076923e-01
#   1.34615385e-01 7.69230769e-02 1.92307692e-01 2.11538462e-01
#   1.73076923e-01 1.53846154e-01 1.11022302e-16 3.26923077e-01
#   5.76923077e-02]]
# [[1.83673039e-01 1.15384615e-01 5.76923077e-02 2.69230769e-01
#   1.73076923e-01 1.34615385e-01 7.69230769e-02 1.92307692e-01
#   2.11538462e-01 1.73076923e-01 1.53846154e-01 1.11022302e-16
#   3.26923077e-01]]
# [[1.56202793e-01 1.92307692e-01 1.15384615e-01 5.76923077e-02
#   2.69230769e-01 1.73076923e-01 1.34615385e-01 7.69230769e-02
#   1.92307692e-01 2.11538462e-01 1.73076923e-01 1.53846154e-01
#   1.11022302e-16]]
# [[0.21616533 0.15384615 0.19230769 0.11538462 0.05769231 0.26923077
#   0.17307692 0.13461538 0.07692308 0.19230769 0.21153846 0.17307692
#   0.15384615]]
# [[0.19467154 0.11538462 0.15384615 0.19230769 0.11538462 0.05769231
#   0.26923077 0.17307692 0.13461538 0.07692308 0.19230769 0.21153846
#   0.17307692]]
# [[-0.00162093  0.38461538  0.11538462  0.15384615  0.19230769  0.11538462
#    0.05769231  0.26923077  0.17307692  0.13461538  0.07692308  0.19230769
#    0.21153846]]
# [[ 0.30411962 -0.07692308  0.38461538  0.11538462  0.15384615  0.19230769
#    0.11538462  0.05769231  0.26923077  0.17307692  0.13461538  0.07692308
#    0.19230769]]
# [[ 0.12452341  0.23076923 -0.07692308  0.38461538  0.11538462  0.15384615
#    0.19230769  0.11538462  0.05769231  0.26923077  0.17307692  0.13461538
#    0.07692308]]
# [[ 0.23356974  0.05769231  0.23076923 -0.07692308  0.38461538  0.11538462
#    0.15384615  0.19230769  0.11538462  0.05769231  0.26923077  0.17307692
#    0.13461538]]
# [[ 0.15942609  0.30769231  0.05769231  0.23076923 -0.07692308  0.38461538
#    0.11538462  0.15384615  0.19230769  0.11538462  0.05769231  0.26923077
#    0.17307692]]
# [[ 0.19429913  0.03846154  0.30769231  0.05769231  0.23076923 -0.07692308
#    0.38461538  0.11538462  0.15384615  0.19230769  0.11538462  0.05769231
#    0.26923077]]
# [[ 0.20982257  0.09615385  0.03846154  0.30769231  0.05769231  0.23076923
#   -0.07692308  0.38461538  0.11538462  0.15384615  0.19230769  0.11538462
#    0.05769231]]
# [[ 0.15518506  0.17307692  0.09615385  0.03846154  0.30769231  0.05769231
#    0.23076923 -0.07692308  0.38461538  0.11538462  0.15384615  0.19230769
#    0.11538462]]
# [[ 0.12734751  0.26923077  0.17307692  0.09615385  0.03846154  0.30769231
#    0.05769231  0.23076923 -0.07692308  0.38461538  0.11538462  0.15384615
#    0.19230769]]
# [[ 0.11782096  0.21153846  0.26923077  0.17307692  0.09615385  0.03846154
#    0.30769231  0.05769231  0.23076923 -0.07692308  0.38461538  0.11538462
#    0.15384615]]
# [[0.15389517 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615]]
# [[0.16035193 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615]]
# [[0.16447523 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615]]
# [[0.16740514 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615]]
# [[0.16954446 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615 0.15384615 0.15384615 0.15384615 0.15384615 0.15384615
#   0.15384615]]

# %%
#reshape pred_test_set
pred_test_set = np.array(pred_test_set)
pred_test_set = pred_test_set.reshape(pred_test_set.shape[0], pred_test_set.shape[2])

# %%
#inverse transform
pred_test_set_inverted = scaler.inverse_transform(pred_test_set)

# %%
#create dataframe that shows the predicted sales
result_list = []
sales_dates = list(df_sales[-31:].date)
act_sales = list(df_sales[-31:].sales)
# pred_test_set_inverted[index][0]

# %%
for index in range(0,len(pred_test_set_inverted)):
    result_dict = {}
    result_dict['pred_value'] = int(pred_test_set_inverted[index][0] + act_sales[index])
    result_dict['date'] = sales_dates[index+1]
    result_list.append(result_dict)
df_result = pd.DataFrame(result_list)

# %%
#merge with actual sales dataframe
df_sales_pred = pd.merge(df_sales,df_result,on='date',how='left')

# %%
from matplotlib.pyplot import figure

figure(figsize=(20, 10), dpi=80)
plt.plot(df_sales_pred['date'], df_sales_pred['sales'], label = "actual")
plt.plot(df_sales_pred['date'], df_sales_pred['pred_value'], label = "predicted")
# plt.plot(x, y, label = "line 1")
# plt.plot(y, x, label = "line 2")
plt.xlabel("Dates")
plt.ylabel("Sales")
plt.legend()
plt.show()
# Out:
# C:\Anaconda3\envs\test\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# C:\Anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Anaconda3\envs\test\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
